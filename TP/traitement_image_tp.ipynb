# %% [markdown]
# # Travaux pratiques de traitement d'image
# ## Filière GSEII S5
# ### Année universitaire 2024-2025
# ---

# %% [markdown]
# ## Objectif du TP
#
# Mettre en pratique les connaissances acquis en cours dans le domaine du traitement d'image bas niveau à travers :
#
# 1. Pratiquer les techniques d'amélioration radiométriques des images en couleurs et en niveau de gris.
#
# 2. Appliquer les techniques de restauration d'image en utilisant différents approches à savoir le fitrage spatiale, spectrale ainsi que les méthodes non linéaires.
#
# 3. Réaliser la segmentation des images en utilisant les méthodes orientées contour et région.

# %%
# Load the autoreload extension
# %reload_ext autoreload
# %autoreload 2

import os
import PIL.Image as Im
import numpy as np
from imtools import ImageDegrader

# %%
student_rank = 1 # Votre rang dans la liste des étudiants
dirname = os.getcwd()
root_folder = os.path.join(dirname, 'original_png')
imDegrader = ImageDegrader(root_folder, student_rank)
im = imDegrader.image
im_deg = imDegrader.apply_all_degradations()
Im.fromarray(np.hstack((np.array(im),np.array(im_deg))))
# Out:
# <PIL.Image.Image image mode=RGB size=962x321>

# %% [markdown]
# ### Travail à réaliser
#
# ### Préléminaires
#
# 1. Écriver un code qui permet de retourner les statistiques de base sur l'image que vous manipulez à savoir
#    + la résolution spatiale
#    + Le type de l'espace couleur utilisé.
#    + la dynamique de chaque canal de couleur
#    + la brillance moyenne
#    + le contraste.

# %%
# Statistique de l'image dégradé.

# %% [markdown]
# #### Analyse radiométrique de l'image
#
# Utiliser l'image dégradée pour réaliser les taches suivantes:

# %% [markdown]
# + Analyse radiométrique de l'image pour le canal de luminosité.

# %%
# Code à ajouter pour l'analyse radiométrique

# %% [markdown]
# + Analyse spectrale de L'image pour le canal de luminiscence et particulièrement le spectre d'amplitude.

# %%
# Code à ajouter pour l'analyse spectrale

# %% [markdown]
# + Faites un check par votre professeur.

# %% [markdown]
# ### Amélioration radiométrique
#
# 1. Pour réaliser l'amélioration radiométrique nous allons provcéder à une utilisation adaptatif de l'égalisation de l'histogramme avec une fenêtre glissante de $21 \times 21$ et un recouvrement de 50\%.
#
# 2. Développer le code necessaire pour réaliser cette amélioration.
#
# 3. Executez le et faites un check.

# %%
# Code de l'égalisation adaptatif de l'image

# %% [markdown]
# #### Analyse et conclusion

# %% [markdown]
# ### Restauration de l'image
#
# 1. Pour réaliser la restauration de l'image nous allons utiliser trois techniques à savoir :
#
#    + Le filtrage spatiale en utilisant un filtre gaussien de taille appropriée.
#
#    + Le filtrage spectrale en utilisant un filtre de Butterworth d'ordre 4 et de diamètre d'action adéquat.
#
#    + Un filtre d'ordre de type médian opérant sur une fenêtre de taille $5 \times 5$.
#
# 2. Développez le code qui permet de ráliser chaque opération ansi que la métrique utilisé pour évaluer la qualité du résultat obtenu.
#
# 3. Executez votre code et faites un check.

# %%
# code du filtrage spatiale

# %%
# Code du filtrage spectrale

# %%
# Code du filtrage d'ordre.

# %%
# Code de comparaison des résultats

# %% [markdown]
# #### Analyse et conclusion

# %% [markdown]
# ### Segmentation de l'image
#
# Dans ce qui suit nous allons appliquer la procédure de segmentation de l'image restauré telle qu'on la vue dans le cours en utilisant l'approche de Canny.

# %% [markdown]
# 1. Rappelez les différentes étapes de cette approche :
#
#    + ___________________________________________________________________________________
#    + ____________________________________________________________________________________
#    + ____________________________________________________________________________________
#    + ___________________________________________________________________________________

# %% [markdown]
# 2. Élaborez le code de chaque étape d'une manière séparée des autres étapes.

# %% [markdown]
# 3. Faites un check de votre travail.

# %% [markdown]
# #### Analyse et conclusion

# %%
rank
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 rank
#
# NameError: name 'rank' is not defined
